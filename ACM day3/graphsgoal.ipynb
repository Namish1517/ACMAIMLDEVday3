# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid",context="notebook")
df = pd.read_csv(r"C:\Users\Namish\OneDrive\Documents\projects\ACM day3\goldenboot.csv")
for col in ["Year","Goals","Age"]:
    df[col]=pd.to_numeric(df[col], errors="coerce")
df = df.dropna(subset=["Year","Goals","Age"]).reset_index(drop=True)

# %%
plt.figure(figsize=(7,5))
sns.histplot(df["Goals"],bins=10,kde=True)
plt.title("Distribution of Goals")
plt.xlabel("Goals")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="Year",y="Goals",hue="Player",legend=False)
plt.title("Goals by Year")
plt.xlabel("Year")
plt.ylabel("Goals")
plt.show()

# %%
plt.figure(figsize=(5,4))
corr=df[["Year","Goals","Age"]].corr()
sns.heatmap(corr,annot=True,cmap="coolwarm",vmin=-1,vmax=1,fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
club_counts=df["Club"].value_counts()
clubs_2plus=club_counts[club_counts>=2].index
plt.figure(figsize=(10,6))
sns.boxplot(data=df[df["Club"].isin(clubs_2plus)],x="Club",y="Goals")
plt.title("Goals by Big Clubs")
plt.xlabel("Club")
plt.ylabel("Goals")
plt.xticks( ha="right")
plt.show()
